# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sns.set_theme()


food_source_color = '#7DC160'
# total_energy_color = '#f4cccc'
fish_energy_color = '#4e73b0'
# 7DC160

# %%
# Get a list of all files which are .csv files in ../DOTSSimulator/Assets/SimulationResults
import os
files = [f for f in os.listdir('.') if f.endswith('.csv')]
# Sort the files descending
files.sort()

print(f'Found {len(files)} files')
print(f'Newest file: {files[0]}')
print(files)
# Out:
# Found 3 files
# Newest file: 3-1-feeding-range-1.csv
# ['3-1-feeding-range-1.csv', '3-2-feeding-range-10.csv', '3-3-up-feeding-rate.csv']

# %%
results_df: pd.DataFrame = pd.read_csv(files[0])
# Print basic information about the dataframe
print(results_df.info())

results_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Step                1064 non-null   int64
#  1   TimeStamp           1064 non-null   float64
#  2   AvgEnergy           1064 non-null   float64
#  3   AverageEnergy_5th   1064 non-null   float64
#  4   AverageEnergy_95th  1064 non-null   float64
#  5   NoBoids             1064 non-null   int64
#  6   NoFoodSources       1064 non-null   int64
#  7   TotalFoodAvailable  1064 non-null   float64
#  8   Polarization        1064 non-null   float64
#  9   Expanse             1064 non-null   float64
# dtypes: float64(7), int64(3)
# memory usage: 83.2 KB
# None
#    Step  TimeStamp  AvgEnergy  AverageEnergy_5th  AverageEnergy_95th  NoBoids  \
# 0     0    0.00100   384.0000           384.0000            384.0000       25
# 1     1   59.87059   384.0692           384.0679            384.0706       25
# 2     2  119.87070   384.1380           384.1364            384.1403       25
# 3     3  179.87070   384.2071           384.2043            384.2099       25
# 4     4  239.87020   384.2755           384.2717            384.2798       25
#
#    NoFoodSources  TotalFoodAvailable  Polarization   Expanse
# 0              1            450.0000      0.492735  4.853849
# 1              1            450.4144      0.494468  0.546763
# 2              1            450.8371      0.421971  0.852761
# 3              1            451.2543      0.480478  0.366447
# 4              1            451.6880      0.447235  0.596588

# %%
# Configuration:

truncated_df_1 = results_df.iloc[1:721]

print(truncated_df_1.describe())

truncated_df_1['AvgEnergy_ymin'] = truncated_df_1['AverageEnergy_5th']
truncated_df_1['AvgEnergy_ymax'] = truncated_df_1['AverageEnergy_95th']

truncated_df_1['TotalFoodAvailable_ymin'] = truncated_df_1['TotalFoodAvailable']
truncated_df_1['TotalFoodAvailable_ymax'] = truncated_df_1['TotalFoodAvailable']

truncated_df_1.info()
truncated_df_1.head()
# Out:
#              Step     TimeStamp   AvgEnergy  AverageEnergy_5th  \
# count  720.000000    720.000000  720.000000         720.000000
# mean   360.500000  21630.864072  408.930160         408.908140
# std    207.990384  12480.242626   14.385177          14.377991
# min      1.000000     59.870590  384.069200         384.067900
# 25%    180.750000  10845.010000  396.496675         396.481600
# 50%    360.500000  21630.470000  408.929300         408.899050
# 75%    540.250000  32417.000000  421.364375         421.336450
# max    720.000000  43202.000000  433.794800         433.759800
#
#        AverageEnergy_95th  NoBoids  NoFoodSources  TotalFoodAvailable  \
# count          720.000000    720.0          720.0          720.000000
# mean           408.960543     25.0            1.0          599.693042
# std             14.397290      0.0            0.0           86.322181
# min            384.070600     25.0            1.0          450.414400
# 25%            396.517725     25.0            1.0          525.129250
# 50%            408.957050     25.0            1.0          599.714600
# 75%            421.408200     25.0            1.0          674.239625
# max            433.839000     25.0            1.0          748.879600
#
#        Polarization     Expanse
# count    720.000000  720.000000
# mean       0.465816    0.794153
# std        0.025761    0.174282
# min        0.362957    0.366447
# 25%        0.451774    0.679380
# 50%        0.471632    0.805640
# 75%        0.485018    0.913796
# max        0.499851    1.801017
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 1 to 720
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Step                     720 non-null    int64
#  1   TimeStamp                720 non-null    float64
#  2   AvgEnergy                720 non-null    float64
#  3   AverageEnergy_5th        720 non-null    float64
#  4   AverageEnergy_95th       720 non-null    float64
#  5   NoBoids                  720 non-null    int64
#  6   NoFoodSources            720 non-null    int64
#  7   TotalFoodAvailable       720 non-null    float64
#  8   Polarization             720 non-null    float64
#  9   Expanse                  720 non-null    float64
#  10  AvgEnergy_ymin           720 non-null    float64
#  11  AvgEnergy_ymax           720 non-null    float64
#  12  TotalFoodAvailable_ymin  720 non-null    float64
#  13  TotalFoodAvailable_ymax  720 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 78.9 KB
# C:\Users\Niels\AppData\Local\Temp\ipykernel_34372\3017156009.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   truncated_df_1['AvgEnergy_ymin'] = truncated_df_1['AverageEnergy_5th']
# C:\Users\Niels\AppData\Local\Temp\ipykernel_34372\3017156009.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   truncated_df_1['AvgEnergy_ymax'] = truncated_df_1['AverageEnergy_95th']
# C:\Users\Niels\AppData\Local\Temp\ipykernel_34372\3017156009.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   truncated_df_1['TotalFoodAvailable_ymin'] = truncated_df_1['TotalFoodAvailable']
# C:\Users\Niels\AppData\Local\Temp\ipykernel_34372\3017156009.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   truncated_df_1['TotalFoodAvailable_ymax'] = truncated_df_1['TotalFoodAvailable']
#    Step  TimeStamp  AvgEnergy  AverageEnergy_5th  AverageEnergy_95th  NoBoids  \
# 1     1   59.87059   384.0692           384.0679            384.0706       25
# 2     2  119.87070   384.1380           384.1364            384.1403       25
# 3     3  179.87070   384.2071           384.2043            384.2099       25
# 4     4  239.87020   384.2755           384.2717            384.2798       25
# 5     5  299.87020   384.3449           384.3408            384.3489       25
#
#    NoFoodSources  TotalFoodAvailable  Polarization   Expanse  AvgEnergy_ymin  \
# 1              1            450.4144      0.494468  0.546763        384.0679
# 2              1            450.8371      0.421971  0.852761        384.1364
# 3              1            451.2543      0.480478  0.366447        384.2043
# 4              1            451.6880      0.447235  0.596588        384.2717
# 5              1            452.0979      0.492135  0.962164        384.3408
#
#    AvgEnergy_ymax  TotalFoodAvailable_ymin  TotalFoodAvailable_ymax
# 1        384.0706                 450.4144                 450.4144
# 2        384.1403                 450.8371                 450.8371
# 3        384.2099                 451.2543                 451.2543
# 4        384.2798                 451.6880                 451.6880
# 5        384.3489                 452.0979                 452.0979

# %%
metrics = ['AvgEnergy', 'TotalFoodAvailable']

melted = pd.melt(truncated_df_1, id_vars=['Step'], value_vars=metrics, var_name='Metric', value_name='Energy / Food available (g)')
melted.rename(columns={'Step': 'Time (hours)'}, inplace=True)
ymin = []
ymax = []
for name in metrics:
    ymin.extend(truncated_df_1[f"{name}_ymin"].to_numpy())
    ymax.extend(truncated_df_1[f"{name}_ymax"].to_numpy())
    pass

melted['ymin'] = ymin
melted['ymax'] = ymax

melted.head()
# Out:
#    Time (hours)     Metric  Energy / Food available (g)      ymin      ymax
# 0             1  AvgEnergy                     384.0692  384.0679  384.0706
# 1             2  AvgEnergy                     384.1380  384.1364  384.1403
# 2             3  AvgEnergy                     384.2071  384.2043  384.2099
# 3             4  AvgEnergy                     384.2755  384.2717  384.2798
# 4             5  AvgEnergy                     384.3449  384.3408  384.3489

# %%
melted.tail()
# Out:
#       Time (hours)              Metric  Energy / Food available (g)      ymin  \
# 1435           716  TotalFoodAvailable                     747.2306  747.2306
# 1436           717  TotalFoodAvailable                     747.6433  747.6433
# 1437           718  TotalFoodAvailable                     748.0486  748.0486
# 1438           719  TotalFoodAvailable                     748.4701  748.4701
# 1439           720  TotalFoodAvailable                     748.8796  748.8796
#
#           ymax
# 1435  747.2306
# 1436  747.6433
# 1437  748.0486
# 1438  748.4701
# 1439  748.8796

# %%
fig = plt.figure(figsize=(15, 5))

sns.lineplot(data=truncated_df_1, x='Step', y='AvgEnergy', label='Average Fish Energy', color=fish_energy_color)
sns.lineplot(data=truncated_df_1, x='Step', y='TotalFoodAvailable', label='Total Food Available', color=food_source_color)
plt.xlabel('Time (hours)')
plt.ylabel('Fish Energy / Food available (g)')
plt.tight_layout()
plt.legend()
 
plt.savefig('plots/exp3-Environment-1.pdf')

# %%
# Compute coefficient in avg energy
min_food = truncated_df_1['TotalFoodAvailable'].min()
max_food = truncated_df_1['TotalFoodAvailable'].max()
print(f'Min food available: {min_food}')
print(f'Max food available: {max_food}')
print(f'Coefficient: {(max_food - min_food) / 30}')

# Compute coefficient in avg energy
min_energy = truncated_df_1['AvgEnergy'].min()
max_energy = truncated_df_1['AvgEnergy'].max()
print(f'Min energy: {min_energy}')
print(f'Max energy: {max_energy}')
coeff = (max_energy - min_energy) / 30
print(f'Coefficient: {(max_energy - min_energy) / 30}')
# Out:
# Min food available: 450.4144
# Max food available: 748.8796
# Coefficient: 9.948839999999999
# Min energy: 384.0692
# Max energy: 433.7948
# Coefficient: 1.6575199999999994

# %%
results_df: pd.DataFrame = pd.read_csv(files[1])
truncated_df_2 = results_df.iloc[1:721]

print(truncated_df_2.describe())
truncated_df_2.info()
truncated_df_2.head()
# Out:
#              Step     TimeStamp   AvgEnergy  NoBoids  NoFoodSources  \
# count  720.000000    720.000000  720.000000    720.0          720.0
# mean   360.500000  21630.917911  414.917694     25.0            1.0
# std    207.990384  12480.260841   17.838064      0.0            0.0
# min      1.000000     59.871060  384.085600     25.0            1.0
# 25%    180.750000  10845.010000  399.501650     25.0            1.0
# 50%    360.500000  21630.560000  414.917700     25.0            1.0
# 75%    540.250000  32417.040000  430.333750     25.0            1.0
# max    720.000000  43202.040000  445.749800     25.0            1.0
#
#        TotalFoodAvailable  Polarization     Expanse
# count        7.200000e+02    720.000000  720.000000
# mean         4.500047e+02      0.465448    0.777647
# std          1.137659e-13      0.025510    0.169015
# min          4.500047e+02      0.321257    0.331554
# 25%          4.500047e+02      0.453017    0.661942
# 50%          4.500047e+02      0.471535    0.779637
# 75%          4.500047e+02      0.483873    0.900327
# max          4.500047e+02      0.499640    1.293079
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 1 to 720
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Step                720 non-null    int64
#  1   TimeStamp           720 non-null    float64
#  2   AvgEnergy           720 non-null    float64
#  3   NoBoids             720 non-null    int64
#  4   NoFoodSources       720 non-null    int64
#  5   TotalFoodAvailable  720 non-null    float64
#  6   Polarization        720 non-null    float64
#  7   Expanse             720 non-null    float64
# dtypes: float64(5), int64(3)
# memory usage: 45.1 KB
#    Step  TimeStamp  AvgEnergy  NoBoids  NoFoodSources  TotalFoodAvailable  \
# 1     1   59.87106   384.0856       25              1            450.0047
# 2     2  119.87110   384.1713       25              1            450.0047
# 3     3  179.87110   384.2571       25              1            450.0047
# 4     4  239.87110   384.3429       25              1            450.0047
# 5     5  299.87110   384.4286       25              1            450.0047
#
#    Polarization   Expanse
# 1      0.469230  0.709151
# 2      0.454103  0.590944
# 3      0.446927  0.785945
# 4      0.445897  0.894300
# 5      0.488847  0.713243

# %%
fig = plt.figure(figsize=(15, 5))

ax = fig.add_subplot()
sns.lineplot(data=truncated_df_2, x='Step', y='AvgEnergy', ax=ax, label='Average Fish Energy', color=fish_energy_color)
sns.lineplot(data=truncated_df_2, x='Step', y='TotalFoodAvailable', ax=ax, label='Total Food Available', color=food_source_color)
plt.xlabel('Time (hours)')
plt.ylabel('Fish Energy / Food available (g)')
plt.tight_layout()
plt.legend()
 
plt.savefig('plots/exp3-Environment-2.pdf')

# %%
# Compute coefficient in avg energy
min_food_2 = truncated_df_2['TotalFoodAvailable'].min()
max_food_2 = truncated_df_2['TotalFoodAvailable'].max()
print(f'Min food available: {min_food_2}')
print(f'Max food available: {max_food_2}')
print(f'Coefficient: {(max_food_2 - min_food_2) / 30}')

# Compute coefficient in avg energy
min_energy_2 = truncated_df_2['AvgEnergy'].min()
max_energy_2 = truncated_df_2['AvgEnergy'].max()
print(f'Min energy: {min_energy_2}')
print(f'Max energy: {max_energy_2}')
coeff_2 = (max_energy_2 - min_energy_2) / 30
print(f'Coefficient: {coeff_2}')
# Out:
# Min food available: 450.0047
# Max food available: 450.0047
# Coefficient: 0.0
# Min energy: 384.0856
# Max energy: 445.7498
# Coefficient: 2.055473333333333

# %%
print(f'Coefficient difference: {coeff_2 - coeff}')
consumptionrate = 0.0000064621913580246909 * 3600 * 24
scale = (coeff_2 + consumptionrate) / (coeff + consumptionrate)
print(f'Coefficient scale: {scale}')

feedingrate = 0.000030285493827160491
new_feedingrate = feedingrate * scale
print(f'New feeding rate: {feedingrate * scale}')

# 0.0000357415 : Brute force value
# Out:
# Coefficient difference: 0.3979533333333336
# Coefficient scale: 1.1795937155888778
# New feeding rate: 3.5724578192024266e-05

# %% [markdown]
# Experiment 3.3 (Adjusted the feeding rate with a scalar previously computed)

# %%
results_df: pd.DataFrame = pd.read_csv(files[2])
# Print basic information about the dataframe
print(results_df.info())

# Configuration:

truncated_df_3 = results_df.iloc[:721]

print(truncated_df_3.describe())
truncated_df_3.info()
truncated_df_3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737 entries, 0 to 736
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Step                737 non-null    int64
#  1   TimeStamp           737 non-null    float64
#  2   AvgEnergy           737 non-null    float64
#  3   AverageEnergy_5th   737 non-null    float64
#  4   AverageEnergy_95th  737 non-null    float64
#  5   NoBoids             737 non-null    int64
#  6   NoFoodSources       737 non-null    int64
#  7   TotalFoodAvailable  737 non-null    float64
#  8   Polarization        737 non-null    float64
#  9   Expanse             737 non-null    float64
# dtypes: float64(7), int64(3)
# memory usage: 57.7 KB
# None
#             Step     TimeStamp   AvgEnergy  AverageEnergy_5th  \
# count  721.00000    721.000000  721.000000         721.000000
# mean   360.00000  21600.850877  414.885743         414.855069
# std    208.27906  12497.538853   17.869303          17.857229
# min      0.00000      0.002000  384.000000         384.000000
# 25%    180.00000  10800.010000  399.440600         399.417900
# 50%    360.00000  21600.540000  414.890600         414.855200
# 75%    540.00000  32401.940000  430.328400         430.289900
# max    720.00000  43201.950000  445.763200         445.721100
#
#        AverageEnergy_95th  NoBoids  NoFoodSources  TotalFoodAvailable  \
# count          721.000000    721.0          721.0          721.000000
# mean           414.928344     25.0            1.0          449.731445
# std             17.885407      0.0            0.0            0.184254
# min            384.000000     25.0            1.0          449.517900
# 25%            399.470200     25.0            1.0          449.586100
# 50%            414.924200     25.0            1.0          449.636000
# 75%            430.390200     25.0            1.0          449.941300
# max            445.820000     25.0            1.0          450.086600
#
#        Polarization     Expanse
# count    721.000000  721.000000
# mean       0.465120    0.789500
# std        0.025421    0.222707
# min        0.327324    0.321142
# 25%        0.453462    0.670108
# 50%        0.470604    0.793731
# 75%        0.483416    0.899896
# max        0.499406    4.853849
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 721 entries, 0 to 720
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Step                721 non-null    int64
#  1   TimeStamp           721 non-null    float64
#  2   AvgEnergy           721 non-null    float64
#  3   AverageEnergy_5th   721 non-null    float64
#  4   AverageEnergy_95th  721 non-null    float64
#  5   NoBoids             721 non-null    int64
#  6   NoFoodSources       721 non-null    int64
#  7   TotalFoodAvailable  721 non-null    float64
#  8   Polarization        721 non-null    float64
#  9   Expanse             721 non-null    float64
# dtypes: float64(7), int64(3)
# memory usage: 56.5 KB
#    Step  TimeStamp  AvgEnergy  AverageEnergy_5th  AverageEnergy_95th  NoBoids  \
# 0     0    0.00200   384.0000           384.0000            384.0000       25
# 1     1   59.85405   384.0858           384.0837            384.0884       25
# 2     2  119.85400   384.1713           384.1692            384.1743       25
# 3     3  179.85400   384.2573           384.2543            384.2602       25
# 4     4  239.85400   384.3427           384.3396            384.3471       25
#
#    NoFoodSources  TotalFoodAvailable  Polarization   Expanse
# 0              1            450.0000      0.492735  4.853849
# 1              1            449.9996      0.458781  0.809646
# 2              1            450.0059      0.440216  0.919394
# 3              1            450.0004      0.480168  0.538648
# 4              1            450.0076      0.476706  0.771789

# %%
fig = plt.figure(figsize=(15, 5))

ax = fig.add_subplot()
sns.lineplot(data=truncated_df_3, x='Step', y='AvgEnergy', ax=ax, label='Average Fish Energy', color=fish_energy_color)
sns.lineplot(data=truncated_df_3, x='Step', y='TotalFoodAvailable', ax=ax, label='Total Food Available', color=food_source_color)
plt.xlabel('Time (hours)')
plt.ylabel('Fish Energy / Food available (g)')
plt.tight_layout()
plt.legend()
 
plt.savefig('plots/exp3-Environment-3.pdf')

# %%
min_energy_3 = truncated_df_3['AvgEnergy'].min()
max_energy_3 = truncated_df_3['AvgEnergy'].max()
print(f'Min energy: {min_energy_3}')
print(f'Max energy: {max_energy_3}')
coeff_3 = (max_energy_3 - min_energy_3) / 30
print(f'Coefficient: {coeff_3}')
# Out:
# Min energy: 384.0
# Max energy: 445.7632
# Coefficient: 2.058773333333333

# %%
fig = plt.figure(figsize=(15, 5))

ax = fig.add_subplot()
sns.lineplot(data=truncated_df_3, x='Step', y='TotalFoodAvailable', ax=ax, color=food_source_color)
plt.xlabel('Time (hours)')
plt.ylabel('Food available (g)')
plt.tight_layout()
 
plt.savefig('plots/exp3-Environment-4.pdf')

# %%
fig = plt.figure(figsize=(15, 5))

ax = fig.add_subplot()
sns.lineplot(data=truncated_df_3[320:340], x='Step', y='AvgEnergy', ax=ax, label='Average Fish Energy', color=fish_energy_color)
plt.xlabel('Time (hours)')
plt.ylabel('Fish Energy (g)')
plt.tight_layout()
 
plt.savefig('plots/exp3-Environment-5.pdf')
